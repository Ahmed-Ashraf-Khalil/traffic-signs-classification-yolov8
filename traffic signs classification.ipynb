# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
model = YOLO('yolov8n-cls.pt') #load pretrained model

# %%
model.train(data = "./traffic_Data",epochs=22,imgsz=128,batch=-1)
# Out:
# Ultralytics YOLOv8.2.8  Python-3.9.13 torch-2.2.2+cpu CPU (Intel Core(TM) i7-6500U 2.50GHz)
# ...

# %% [markdown]
# # --------------------- time for the test ---------------------

# %%
model = YOLO('./runs/classify/train/weights/best.pt') #load pretrained model

# %%
Image(filename='./traffic_Data/test/001_0004_j.png')

# %%
results = model(["./traffic_Data/test/001_0004_j.png"])
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
# Out:
# 0: 128x128 Speed limit (15km per h) 1.00, Dont overtake from Left 0.00, Go straight or right 0.00, Speed limit (40km per h) 0.00, Go left or straight 0.00, 10.0ms
# Speed: 7.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)

# %%
Image(filename='./traffic_Data/test/002_0022.png')

# %%
results = model(["./traffic_Data/test/002_0022.png"])
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
# Out:
# 0: 128x128 Speed limit (30km per h) 1.00, Speed limit (50km per h) 0.00, Speed limit (40km per h) 0.00, No Uturn 0.00, Speed limit (60km per h) 0.00, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)

# %%
Image(filename='./traffic_Data/test/005_0004_j.png')

# %%
results = model(["./traffic_Data/test/005_0004_j.png"])
# Out:
# 0: 128x128 Speed limit (60km per h) 0.81, speed limit (80km per h) 0.07, Speed limit (30km per h) 0.05, Speed limit (40km per h) 0.02, Speed limit (50km per h) 0.02, 18.0ms
# Speed: 6.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
